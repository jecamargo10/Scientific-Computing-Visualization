# %% [markdown]
# # Exercises Week 1

# %% [markdown]
# vtkLookupTable: Maps scalar values into RGBA specification or RGBA into scalar values.
#
# vtkColorTransferFunction: Maps RGB or HSV spaces to allow the interpolation of those.

# %% [markdown]
# With thise functions I can change the color scale of certain scalar values and create the asociated graph

# %% [markdown]
# Example

# %% [markdown]
# ![greenColor.PNG](attachment:greenColor.PNG)

# %% [markdown]
# ![Purlple%20color.PNG](attachment:Purlple%20color.PNG)
