# %% [markdown]
# # Exercises Week 1

# %% [markdown]
# #### I tried to do the same process of the simulation that we do in the laboratory and change the figure to a square. The process was similar but the fact it was a square change the process of creating the SU2 mesh in Salome

# %% [markdown]
# #### First Change:
# #### In the creation of the groups, I have to manually define what segments of the squares form part of the Surface and the Fairfield, I have to select one by one. It doesn’t understand that they are the same like it happens with the Disk, I got the following figure:

# %% [markdown]
# ![surface1.PNG](attachment:surface1.PNG)

# %% [markdown]
# #### Second Change:	I use the same proportions and configurations that we did in the example, but in this case the figure was more complicated, because of that when I run the simulation with SU2,it was taking so much time that I have to stop it, the values were having the expected behavior, 25 minutes had already passed and yet it doesn’t seem to end.

# %% [markdown]
# ![trianglesIndeep.PNG](attachment:trianglesIndeep.PNG)

# %% [markdown]
# ![Triangles.png](attachment:Triangles.png)

# %% [markdown]
# #### I asked to Kathrin for help and she told me that my Geometry was too big and I have to use less segments in the Surface, that it’s more important have a big resolution only on the Fairfield. So I take her advise and the simluation converges to a value and it only takes 3 minutos to do it. The result was the following:

# %% [markdown]
# ![finaly.PNG](attachment:finaly.PNG)

# %% [markdown]
# #### One thing to take in care is that with using low resolution in the surface it is very evident, but since it is not the main feature that we are evaluating therefore it's a concession that can be made

# %% [markdown]
# ![yeahhh.PNG](attachment:yeahhh.PNG)
